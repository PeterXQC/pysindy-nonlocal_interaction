# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
# Load all the coefficients
files = glob.glob('*WF.npy')
integral = [np.load(file) for file in files]

# %%
np.shape(integral[0])
# Out:
# (127,)

# %%
integral[60]
# Out:
# array([[0.02441406, 0.04882812, 0.04882812, 0.04882812, 0.04882812,
#         0.04882812, 0.04882812, 0.04882812, 0.04882812, 0.04882812,
#         0.04882812, 0.04882812, 0.04882812, 0.04882812, 0.04882812,
#         0.04882812, 0.04882812, 0.04882812, 0.04882812, 0.04882812,
#         0.04882812, 0.04882812, 0.04882812, 0.04882812, 0.04882812,
#         0.04882812, 0.04882812, 0.04882812, 0.04882812, 0.04882812,
#         0.02441406],
#        [0.04882812, 0.09765625, 0.09765625, 0.09765625, 0.09765625,
#         0.09765625, 0.09765625, 0.09765625, 0.09765625, 0.09765625,
#         0.09765625, 0.09765625, 0.09765625, 0.09765625, 0.09765625,
#         0.09765625, 0.09765625, 0.09765625, 0.09765625, 0.09765625,
#         0.09765625, 0.09765625, 0.09765625, 0.09765625, 0.09765625,
#         0.09765625, 0.09765625, 0.09765625, 0.09765625, 0.09765625,
#         0.04882812],
#        [0.04882812, 0.09765625, 0.09765625, 0.09765625, 0.09765625,
# ...
